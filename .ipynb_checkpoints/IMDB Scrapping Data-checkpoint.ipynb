# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup as bs
import requests

import pandas as pd

# %% [markdown]
# ## Getting urls and genres to search

# %% [markdown]
# To change the genre of the contents, we just have to add something in genre.
# Example:
#
# movie_genre = 'comedy'

# %%
def movie_scrap(option):
    contents = soup_movie.find_all('div', class_ = 'lister-item mode-advanced')
    if option == 1:
        for content in contents:
            if content.find('span', attrs = {'class':'certificate'}) is not None:
            # The name of the movie
                movies_name = content.h3.a.text
                movies_names.append(movies_name)
            # The year of the movie
                movies_year = content.h3.find('span', class_ = 'lister-item-year').text
                if movies_year[1].isdigit() == False:
                    movies_year = movies_year.strip('(I) (')
                else:
                    movies_year = movies_year.strip('()')
                movies_years.append(movies_year)
            # The rating of the movie
                movies_imdb = float(content.strong.text)
                movies_imdb_ratings.append(movies_imdb)
            # The number of votes of the movie
                movies_vote = content.find('span', attrs = {'name':'nv'})['data-value']
                movies_votes.append(int(movies_vote))
            #the Age rating of the movie
                movies_age_rating = content.find('span', attrs = {'class':'certificate'}).text
                movies_ages.append(movies_age_rating)
            #The runtime of the movie
                movies_runtime = content.find('span', attrs = {'class':'runtime'}).text.strip(' min')
                movies_runtimes.append(movies_runtime)
            #The genres of the movie
                movies_genre = content.find('span', attrs = {'class':'genre'}).text.strip()
                movies_genres.append(movies_genre)
    
    elif option == 2:
        for content in contents:
            if content.find('span', attrs = {'class':'certificate'}) is not None and content.find('span', attrs = {'class':'runtime'}) is not None:
            # The name of the serie
                series_name = content.h3.a.text
                series_names.append(series_name)
            # The year of the serie
                series_year = content.h3.find('span', class_ = 'lister-item-year').text
                series_years.append(series_year)
            # The rating of the serie
                series_imdb = float(content.strong.text)
                series_imdb_ratings.append(series_imdb)
            # The number of votes of the serie
                series_vote = content.find('span', attrs = {'name':'nv'})['data-value']
                series_votes.append(int(series_vote))
            #the Age rating of the serie
                series_age_rating = content.find('span', attrs = {'class':'certificate'}).text
                series_ages.append(series_age_rating)
            #The runtime of the serie
                series_runtime = content.find('span', attrs = {'class':'runtime'}).text.strip(' min')
                series_runtimes.append(series_runtime)
            #The genres of the serie
                series_genre = content.find('span', attrs = {'class':'genre'}).text.strip()
                series_genres.append(series_genre)
    
    elif option == 3:
        for content in game_contents:
            if content.find('span', attrs = {'class':'certificate'}) is not None:
            # The name of the game
                game_name = content.h3.a.text
                game_names.append(game_name)
            # The year of the game
                game_year = content.h3.find('span', class_ = 'lister-item-year').text.strip('( Video Game)')
                game_years.append(game_year)
            # The rating of the game
                game_imdb = float(content.strong.text)
                game_imdb_ratings.append(game_imdb)
            # The number of votes of the game
                game_vote = content.find('span', attrs = {'name':'nv'})['data-value']
                game_votes.append(int(game_vote))
            #the Age rating of the game
                game_age_rating = content.find('span', attrs = {'class':'certificate'}).text
                game_ages.append(game_age_rating)
            #The genres of the game
                game_genre = content.find('span', attrs = {'class':'genre'}).text.strip()
                game_genres.append(game_genre)

# %%
movie_genre = ''

movies_names = []
movies_years = []
movies_imdb_ratings = []
movies_metascores = []
movies_votes = []
movies_ages = []
movies_runtimes = []
movies_genres = []

requisition = 0
while len(movies_names) < 1000:
    url_movie = 'https://www.imdb.com/search/title/?title_type=feature&release_date=2015-01-01,2020-12-31&genres='+movie_genre+'&sort=num_votes,desc&count=250&start='+str(requisition)
    movies_req = requests.get(url_movie)
    soup_movie = bs(movies_req.text, 'lxml')
    requisition = requisition+ 251
    movie_scrap(1)

# %%
movies_names
# Out:
# ['Deadpool',
#  'Star Wars: O Despertar da Força',
#  'Mad Max: Estrada da Fúria',
#  'Vingadores: Guerra Infinita',
#  'Perdido em Marte',
#  'Vingadores: Era de Ultron',
#  'O Regresso',
#  'Vingadores: Ultimato',
#  'Capitão América: Guerra Civil',
#  'Batman vs Superman: A Origem da Justiça',
#  'Logan',
#  'Coringa',
#  'Divertida Mente',
#  'Pantera Negra',
#  'Esquadrão Suicida',
#  'Jurassic World: O Mundo dos Dinossauros',
#  'Doutor Estranho',
#  'A Chegada',
#  'Homem-Formiga',
#  'Thor: Ragnarok',
#  'Guardiões da Galáxia Vol. 2',
#  'Mulher-Maravilha',
#  'Star Wars: Os Últimos Jedi',
#  'Rogue One: Uma História Star Wars',
#  'Dunkirk',
#  'Os Oito Odiados',
#  'Homem-Aranha: De Volta ao Lar',
#  'La La Land: Cantando Estações',
#  'Corra!',
#  'Era uma Vez um Deadpool',
#  'It: A Coisa',
#  'Blade Runner 2049',
#  'Bohemian Rhapsody',
#  'Zootopia',
#  'Em Ritmo de Fuga',
#  'Até o Último Homem',
#  'Capitã Marvel',
#  'Fragmentado',
# ...

# %%
serie_genre = ''

series_names = []
series_years = []
series_imdb_ratings = []
series_metascores = []
series_votes = []
series_ages = []
series_runtimes = []
series_genres = []

requisition_series = 0
while len(series_names) < 1000:
    url_serie = 'https://www.imdb.com/search/title/?title_type=tv_series&release_date=2015-01-01,2020-12-31&genres='+serie_genre+'&sort=num_votes,desc&count=250&start='+str(requisition_series)
    series_req = requests.get(url_serie)
    soup_serie = bs(series_req.text, 'lxml')
    requisition_series = requisition_series+ 251
    movie_scrap(2)

# %%
series_names
# Out:
# ['Todo Dia',
#  'The Art of Self-Defense',
#  'Nu',
#  'Batman Ninja',
#  'Exorcistas do Vaticano',
#  'Alvin e os Esquilos: Na Estrada',
#  'A Casa do Medo',
#  'Fim do Mundo',
#  'Cadáver',
#  'Wheelman: Motorista de Fuga',
#  'Virando a Noite',
#  'Southbound',
#  'O Programa',
#  'Apocalipse',
#  'Creep 2',
#  'The Professor',
#  'A Casa Torta',
#  'A Festa',
#  'Adoráveis Mulheres',
#  'Maggie Tem Um Plano',
#  'A Máquina',
#  'Crimes Obscuros',
#  'Juliet, Nua e Crua',
#  'Pelé: O Nascimento de uma Lenda',
#  'A Árvore dos Frutos Selvagens',
#  'Obsessão Secreta',
#  'Goosebumps 2: Halloween Assombrado',
#  'Enjaulada',
#  'A Assassina',
#  'Bem-vindos a Marwen',
#  'O Retorno de Ben',
#  'O Príncipe do Natal',
#  'Security',
#  'O Estado das Coisas',
#  'Os Jovens Titãs em Ação! Nos Cinemas',
#  'Brain on Fire',
#  'As Aventuras de Brigsby Bear',
#  'Abominável',
#  'O Relatório',
#  'Um Monstro no Caminho',
#  'Monster Trucks',
# ...

# %%
request_test = requests.get('https://www.imdb.com/search/title/?title_type=movies&release_date=2015-01-01,2020-12-31&genres='+serie_genre+'&sort=num_votes,desc&count=250&start='+str(requisition_series))a

# %%
bs(request_test.text)
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Released between 2015-01-01 and 2020-12-31,
# Action
# (Sorted by Number of Votes Descending) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
# ...

# %%
series_names
# Out:
# ['Todo Dia',
#  'The Art of Self-Defense',
#  'Nu',
#  'Batman Ninja',
#  'Exorcistas do Vaticano',
#  'Alvin e os Esquilos: Na Estrada',
#  'A Casa do Medo',
#  'Fim do Mundo',
#  'Cadáver',
#  'Wheelman: Motorista de Fuga',
#  'Virando a Noite',
#  'Southbound',
#  'O Programa',
#  'Apocalipse',
#  'Creep 2',
#  'The Professor',
#  'A Casa Torta',
#  'A Festa',
#  'Adoráveis Mulheres',
#  'Maggie Tem Um Plano',
#  'A Máquina',
#  'Crimes Obscuros',
#  'Juliet, Nua e Crua',
#  'Pelé: O Nascimento de uma Lenda',
#  'A Árvore dos Frutos Selvagens',
#  'Obsessão Secreta',
#  'Goosebumps 2: Halloween Assombrado',
#  'Enjaulada',
#  'A Assassina',
#  'Bem-vindos a Marwen',
#  'O Retorno de Ben',
#  'O Príncipe do Natal',
#  'Security',
#  'O Estado das Coisas',
#  'Os Jovens Titãs em Ação! Nos Cinemas',
#  'Brain on Fire',
#  'As Aventuras de Brigsby Bear',
#  'Abominável',
#  'O Relatório',
#  'Um Monstro no Caminho',
#  'Monster Trucks',
# ...
